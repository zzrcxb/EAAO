# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

from toolkit import *
from pathlib import Path
from dataclasses import dataclass, field

from itertools import combinations
from collections import defaultdict, namedtuple
from dataclasses import dataclass, field
from typing import *

gcp_logger.setLevel(logging.INFO)

n_conns = 800  # number of container instances to create
duration = 180  # sleep for some time before the validation (to occupy more hosts)
region = 'us-central1'
service_url = ''  # Put your service URL here

# %%
# validation measurements

if duration:
    conns = await connect_ts_sockets(service_url, n_conns)
    await disconnect_ts_sockets(conns)
    time.sleep(duration)

# AMD CPUs does not appear to have the rdseed covert channel, so we grab Intel machine only
# When we conducted the experiment, only Intel CPUs were observed
conns = await connect_ts_sockets(service_url, n_conns,
                                 extra_filter=lambda c: c.greeting.rdseed_support and c.greeting.is_intel)
mgroups = group_by_attrib(conns, func=lambda c: c.greeting.machine)
validator = FinpValidator(dict(), emitter_factory=RdseedEmitter)
grps, failed = await validator.validate(conns)
await disconnect_ts_sockets(conns)
print(f'{len(grps)} groups, {len(failed)} failed conns')
res = [{c.greeting for c in grp} for grp in grps]
val_res = res
# Out:
# [INFO] 2024-04-29 08:50:42,183@MainThread: A burst of 800 HTTP requests to https://eaao-t2dkbl7zea-uc.a.run.app/ takes 12.956s
# [INFO] 2024-04-29 08:50:52,489@MainThread: Filtered out 142 SocketIO connections
# [INFO] 2024-04-29 08:50:52,491@MainThread: https://eaao-t2dkbl7zea-uc.a.run.app/: 574 healthy SocketIO connections so far.
# [INFO] 2024-04-29 08:51:05,801@MainThread: Filtered out 39 SocketIO connections
# [INFO] 2024-04-29 08:51:05,803@MainThread: https://eaao-t2dkbl7zea-uc.a.run.app/: 691 healthy SocketIO connections so far.
# [INFO] 2024-04-29 08:51:18,958@MainThread: Filtered out 20 SocketIO connections
# [INFO] 2024-04-29 08:51:18,960@MainThread: https://eaao-t2dkbl7zea-uc.a.run.app/: 743 healthy SocketIO connections so far.
# [INFO] 2024-04-29 08:51:32,105@MainThread: Filtered out 11 SocketIO connections
# [INFO] 2024-04-29 08:51:32,108@MainThread: https://eaao-t2dkbl7zea-uc.a.run.app/: 775 healthy SocketIO connections so far.
# [INFO] 2024-04-29 08:51:45,241@MainThread: Filtered out 3 SocketIO connections
# [INFO] 2024-04-29 08:51:45,244@MainThread: https://eaao-t2dkbl7zea-uc.a.run.app/: 794 healthy SocketIO connections so far.
# [INFO] 2024-04-29 08:51:58,383@MainThread: Filtered out 2 SocketIO connections
# [INFO] 2024-04-29 08:51:58,386@MainThread: https://eaao-t2dkbl7zea-uc.a.run.app/: 797 healthy SocketIO connections so far.
# [INFO] 2024-04-29 08:52:11,516@MainThread: Filtered out 1 SocketIO connections
# [INFO] 2024-04-29 08:52:11,519@MainThread: https://eaao-t2dkbl7zea-uc.a.run.app/: 798 healthy SocketIO connections so far.
# [INFO] 2024-04-29 08:52:15,677@MainThread: Filtered out 1 SocketIO connections
# [INFO] 2024-04-29 08:52:15,680@MainThread: https://eaao-t2dkbl7zea-uc.a.run.app/: 799 healthy SocketIO connections so far.
# [INFO] 2024-04-29 08:52:18,804@MainThread: Filtered out 1 SocketIO connections
# [INFO] 2024-04-29 08:52:18,806@MainThread: https://eaao-t2dkbl7zea-uc.a.run.app/: 799 healthy SocketIO connections so far.
# [INFO] 2024-04-29 08:52:22,956@MainThread: https://eaao-t2dkbl7zea-uc.a.run.app/: 800 healthy SocketIO connections so far.
# [INFO] 2024-04-29 08:52:22,958@MainThread: Trying to connect 800 sockets takes 100.770s
# [INFO] 2024-04-29 08:52:23,531@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:23,858@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:24,148@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:24,172@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:24,217@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:24,256@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:24,470@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:24,605@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:25,034@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:25,103@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:25,246@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:25,939@MainThread: 6 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:26,609@MainThread: 10 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:27,111@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:27,748@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:28,323@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:28,657@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:28,925@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:29,489@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:30,363@MainThread: 10 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:30,400@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:31,557@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:31,867@MainThread: 10 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:32,460@MainThread: 5 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:32,770@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:33,909@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:34,527@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:35,143@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:35,454@MainThread: 2 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:36,008@MainThread: 5 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:36,300@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:37,486@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:37,753@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:38,959@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:39,792@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:41,294@MainThread: 10 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:42,468@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:43,639@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:44,787@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:46,337@MainThread: 6 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:47,218@MainThread: 6 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:48,060@MainThread: 6 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:48,364@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:48,672@MainThread: 2 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:49,540@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:49,836@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:51,050@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:51,905@MainThread: 6 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:52,165@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:53,300@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:53,565@MainThread: 2 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:54,144@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:54,436@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:55,647@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:57,149@MainThread: 10 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:52:58,583@MainThread: 10 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:00,053@MainThread: 10 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:01,215@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:02,416@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:03,010@MainThread: 5 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:03,613@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:04,503@MainThread: 6 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:04,750@MainThread: 2 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:05,669@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:06,549@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:07,667@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:08,850@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:09,147@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:10,013@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:10,889@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:11,165@MainThread: 2 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:11,479@MainThread: 2 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:12,088@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:12,362@MainThread: 2 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:13,529@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:14,401@MainThread: 6 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:14,677@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:14,909@MainThread: 2 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:16,104@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:17,226@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:18,356@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:19,180@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:20,051@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:20,597@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:21,428@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:22,031@MainThread: 5 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:22,280@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:23,768@MainThread: 10 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:24,601@MainThread: 6 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:26,058@MainThread: 10 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:26,601@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:27,155@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:27,432@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:27,697@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:28,900@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:29,503@MainThread: 5 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:30,404@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:30,996@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:31,299@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:32,181@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:32,481@MainThread: 2 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:33,386@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:34,597@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:35,803@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:36,368@MainThread: 4 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:37,531@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:38,395@MainThread: 6 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:39,545@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:39,834@MainThread: 2 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:40,664@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:41,573@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:42,453@MainThread: 6 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:43,633@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:44,783@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:45,908@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:46,774@MainThread: 7 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:47,904@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:49,124@MainThread: 9 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:50,286@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:50,594@MainThread: 2 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:51,752@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:51,977@MainThread: 3 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:53,178@MainThread: 8 conns are grouped to 1 hosts
# [INFO] 2024-04-29 08:53:53,180@MainThread: Model Intel(R) Xeon(R) Platinum 8173M CPU @ 2.00GHz has 131 conns to group
# [INFO] 2024-04-29 08:53:53,181@MainThread: Model Intel(R) Xeon(R) Platinum P-8136 CPU @ 2.00GHz has 11 conns to group
# [INFO] 2024-04-29 08:53:53,183@MainThread: Model Intel(R) Xeon(R) Gold 6253CL CPU @ 3.10GHz has 4 conns to group
# [INFO] 2024-04-29 08:53:53,184@MainThread: Model Intel(R) Xeon(R) Platinum 8273CL CPU @ 2.20GHz has 3 conns to group
# [INFO] 2024-04-29 08:53:53,185@MainThread: Model Intel(R) Xeon(R) CPU E5-2696 v4 @ 2.20GHz has 2 conns to group
# [INFO] 2024-04-29 08:53:53,880@MainThread: Screen unlikely initial try had too many desyncs. 445 desyncs; 55 valid; fallback to pair-wise
# [INFO] 2024-04-29 08:53:53,883@MainThread: 4/4 conns are pre-screened
# [INFO] 2024-04-29 08:53:53,884@MainThread: 4 conns are grouped to 4 hosts
# [INFO] 2024-04-29 08:53:53,894@MainThread: Screen unlikely initial try got 48 desyncs; 452 valid
# [INFO] 2024-04-29 08:53:53,895@MainThread: 2 conns are grouped to 2 hosts
# [INFO] 2024-04-29 08:53:53,908@MainThread: Screen unlikely initial try got 84 desyncs; 416 valid
# [INFO] 2024-04-29 08:53:53,909@MainThread: 3 conns are grouped to 3 hosts
# [INFO] 2024-04-29 08:53:54,045@MainThread: Screen unlikely initial try had too many desyncs. 500 desyncs; 0 valid; fallback to pair-wise
# [INFO] 2024-04-29 08:53:57,106@MainThread: 131/131 conns are pre-screened
# [INFO] 2024-04-29 08:53:57,108@MainThread: 131 conns are grouped to 131 hosts
# [INFO] 2024-04-29 08:53:57,121@MainThread: Screen unlikely initial try got 175 desyncs; 325 valid
# [INFO] 2024-04-29 08:53:57,123@MainThread: 11 conns are grouped to 11 hosts
# [INFO] 2024-04-29 08:53:57,124@MainThread: Validating 800 fingerprints takes 94.114s
# 151 groups, 0 failed conns

# %%
# data process
from sklearn.metrics.cluster import fowlkes_mallows_score, contingency_matrix

@dataclass
class ClusteringScore:
    fmi: float
    samples: int
    pairs: int
    TP: int
    FP: int
    TN: int
    FN: int
    config: Dict
    FP_grps: List[List[TsResp]] = field(default_factory=list)
    FN_grps: List[List[TsResp]] = field(default_factory=list)
    FN_pairs: List[Tuple[TsResp, TsResp]] = field(default_factory=list)
    FP_pairs: List[Tuple[TsResp, TsResp]] = field(default_factory=list)

    @property
    def precision(self):
        return self.TP / (self.TP + self.FP)

    @property
    def recall(self):
        return self.TP / (self.TP + self.FN)


def calc_score(grps: List[Set[TsResp]], ret_pairs: bool = False, **kwargs):
    resps = [r for grp in grps for r in grp]
    oracle_label_map = {r: i for i, grp in enumerate(grps) for r in grp}
    olabels = [oracle_label_map[r] for r in resps]
    plabels = [hash(r.get_machine(**kwargs)) for r in resps]

    m_grps = group_by_attrib(resps, func=lambda r: r.get_machine(**kwargs))
    m_uniq = {m: len({oracle_label_map[r] for r in grp}) for m, grp in m_grps.items()}
    fp_grps = []
    for m, cnt in m_uniq.items():
        if cnt > 1:
            fp_grps.append(m_grps[m])

    fn_grps = []
    for grp in grps:
        if len({r.get_machine(**kwargs) for r in grp}) > 1:
            fn_grps.append(grp)

    n_samples = len(resps)
    n_pairs = (n_samples - 1) * n_samples // 2

    fmi = fowlkes_mallows_score(olabels, plabels, sparse=True)
    c = contingency_matrix(olabels, plabels, sparse=True).astype(np.int64, copy=False)
    tp = (np.dot(c.data, c.data) - n_samples) // 2
    fp = (np.sum(np.asarray(c.sum(axis=0)).ravel() ** 2) - n_samples) // 2 - tp
    fn = (np.sum(np.asarray(c.sum(axis=1)).ravel() ** 2) - n_samples) // 2 - tp
    tn = n_pairs - tp - fp - fn

    fn_pairs, fp_pairs = [], []
    if ret_pairs:
        for r1, r2 in combinations(resps, 2):
            if oracle_label_map[r1] == oracle_label_map[r2] and \
               r1.get_machine(**kwargs) != r2.get_machine(**kwargs):
                fn_pairs.append((r1, r2))
            elif oracle_label_map[r1] != oracle_label_map[r2] and \
               r1.get_machine(**kwargs) == r2.get_machine(**kwargs):
                fp_pairs.append((r1, r2))

    return ClusteringScore(fmi, n_samples, n_pairs, tp, fp, tn, fn,
                           kwargs, fp_grps, fn_grps, fn_pairs, fp_pairs)


def get_score_mean_std(score_lists: List[List[ClusteringScore]],
                       attrib: str) -> Tuple[np.ndarray, np.ndarray]:
    data = np.array([[getattr(s, attrib) for s in sl] for sl in score_lists], dtype=np.float64)
    return np.mean(data, axis=0), np.std(data, axis=0)

# %%
print(f'FMI: {calc_score(val_res).fmi}')
# Out:
# FMI: 1.0
